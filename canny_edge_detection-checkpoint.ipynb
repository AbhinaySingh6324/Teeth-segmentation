# %% [markdown]
# # Code

# %%
"""
import cv2
import numpy as np

#To Capture Real Time Feed From The Web Cam
#cap = cv2.VideoCapture(0)


while(1):

    #Capture a Frame from the real time feed 
    #_, frame = cap.read()
    
    #Opening a Stored Image
    cap=cv2.imread("2.jpg")
    frame=cap
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('Original',frame)
    edges = cv2.Canny(frame,100,150)
    cv2.imshow('Edges',edges)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
#cap.release()
"""
# Out:
# '\nimport cv2\nimport numpy as np\n\n#To Capture Real Time Feed From The Web Cam\n#cap = cv2.VideoCapture(0)\n\n\nwhile(1):\n\n    #Capture a Frame from the real time feed \n    #_, frame = cap.read()\n    \n    #Opening a Stored Image\n    cap=cv2.imread("2.jpg")\n    frame=cap\n    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)\n    \n    lower_red = np.array([30,150,50])\n    upper_red = np.array([255,255,180])\n    \n    mask = cv2.inRange(hsv, lower_red, upper_red)\n    res = cv2.bitwise_and(frame,frame, mask= mask)\n\n    cv2.imshow(\'Original\',frame)\n    edges = cv2.Canny(frame,100,150)\n    cv2.imshow(\'Edges\',edges)\n\n    k = cv2.waitKey(5) & 0xFF\n    if k == 27:\n        break\n\ncv2.destroyAllWindows()\ncap.release()\n'

# %% [markdown]
# # Libraried Required

# %%
import cv2
import numpy as np

# %% [markdown]
# # To Capture Real Time Video from the webcam

# %%
#To Capture Real Time Feed From The Web Cam
#cap = cv2.VideoCapture(0)

# %% [markdown]
# # Edge Detection

# %%
while(1):

    #Capture a Frame from the real time feed 
    #_, frame = cap.read()
    
    
    
    #Opening a Stored Image
    cap=cv2.imread("1.jpg")
    frame=cap
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('Original',frame)
    edges = cv2.Canny(frame,100,150)
    cv2.imshow('Edges',edges)
    
    # Exit Condition wait 5 msec and Esc is pressed
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
#cap.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a765aa006225> in <module>
#      27
#      28 cv2.destroyAllWindows()
# ---> 29 cap.release()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'release'

# %% [markdown]
# # Result

# %%
#from IPython import display
#display.Image("canny_edge_detection_result1.png")

# %% [markdown]
# ![canny_edge_detection_result1.png](attachment:canny_edge_detection_result1.png)
